# %% [markdown]
# Name: Tamanna Shaikh
#
# Roll No: 24102A2006
#
# *R-Programming*
#
# **Lab 3**

# %% [markdown]
# ***BASICS OP CALCULATIONS***
#
# **R as a Calculator with Scalars and Data Vectors :**
#
#
# Power operations, Integer and Modulo **divisions**

# %% [markdown]
# ***R AS CALCULATOR***

# %%
2^3 # POWER OPERATOR COMMAND
# Out:
# 1

# %%
2**3 #POWER OPERATOR COMMAND
# Out:
# 8

# %%
2^5
# Out:
# 7

# %%
2**0.5
# Out:
# 1.4142135623730951

# %%
2^-0.5
# Out:
# [1] 0.7071068

# %% [markdown]
# ***POWER OPERATOR WITH SCALAR***

# %%
c(2,3,5,7)^2
# Out:
# [1]  4  9 25 49

# %%
c(2,3.5,7)^c(2,3)
# Out:
# Warning message in c(2, 3.5, 7)^c(2, 3):
# “longer object length is not a multiple of shorter object length”
# [1]  4.000 42.875 49.000

# %% [markdown]
# ***POWER OPERATION WITH VECTOR***

# %%
c(1,2,3,4,5,6)^c(2,3,4)
# Out:
# [1]    1    8   81   16  125 1296

# %%
c(2,3,5,7)^c(2,3,4)
# Out:
# Warning message in c(2, 3, 5, 7)^c(2, 3, 4):
# “longer object length is not a multiple of shorter object length”
# [1]   4  27 625  49

# %% [markdown]
# ***INTEGER DIVISON WITH SCALAR***

# %% [markdown]
# Integer Division: Division in which the fractional part
# (remainder) is discarded

# %%
2 %/% 2
# Out:
# [1] 1

# %%
5 %/% 2
# Out:
# [1] 2

# %%
7 %/% 3
# Out:
# [1] 2

# %%
c(2,3,5,7) %/% 2
# Out:
# [1] 1 1 2 3

# %%
c(2,3,5,7) %/% c(2,3)
# Out:
# [1] 1 1 2 2

# %% [markdown]
# ***INTEGER DIVISION WITH DATA VECTOR***

# %%
c(2,3,5) %/% c(2,3)
# Out:
# Warning message in c(2, 3, 5)%/%c(2, 3):
# “longer object length is not a multiple of shorter object length”
# [1] 1 1 2

# %% [markdown]
# ***MODULO DIVISION (X MOD Y) WITH SCALARS***

# %% [markdown]
# Modulo Division: modulo operation finds the remainder
# after division of one number by another

# %%
2 %% 2
# Out:
# [1] 0

# %%
3 %% 2
# Out:
# [1] 1

# %%
7 %% 3
# Out:
# [1] 1

# %%
7 %% 4
# Out:
# [1] 3

# %%
c(2,3,5,7) %% 2
# Out:
# [1] 0 1 1 1

# %%
c(2,3,5,7) %% c(2,3)
# Out:
# [1] 0 0 1 1

# %%
c(2,3,5) %% c(2,3)
# Out:
# Warning message in c(2, 3, 5)%%c(2, 3):
# “longer object length is not a multiple of shorter object length”
# [1] 0 0 1

# %% [markdown]
# ***BUILT IN FUNCTIONS AND ASSIGNMENTS***

# %% [markdown]
# ***MAXIMUM***

# %%
#operator:max

# %%
max(1.2, 3.4, -7.8)
# Out:
# [1] 3.4

# %%
max( c(1.2, 3.4, -7.4))
# Out:
# [1] 3.4

# %% [markdown]
# ***MAXIMUM***

# %%
min(1.2, 3.4, -7.8)
# Out:
# [1] -7.8

# %%
min(c(1.2, 3.4, -7.8))
# Out:
# [1] -7.8

# %% [markdown]
# ***ARITHMETIC MEAN***

# %%
mean(2, 3, 4)
# Out:
# [1] 2

# %%
mean(c(2, 3, 4))
# Out:
# [1] 3

# %% [markdown]
# ***OTHER FUNCTIONS***

# %%
abs(-4) #abs finds out absolute value
# Out:
# [1] 4

# %%
abs(c(-1,-2,-3,4,5))
# Out:
# [1] 1 2 3 4 5

# %%
sqrt(4) #sqrt finds square root of values
# Out:
# [1] 2

# %%
sqrt(c(4,9,16,25))
# Out:
# [1] 2 3 4 5

# %%
sum(c(2,3,5,7)) #sum finds sum of all values
# Out:
# [1] 17

# %%
prod(c(2,3,5,7)) #prod finds out the product of all values
# Out:
# [1] 210

# %%
round(1.23) #round finds out the round off values
# Out:
# [1] 1

# %%
round(1.83)
# Out:
# [1] 2

# %%
log(10) #log finds out the log(ln) values
# Out:
# [1] 2.302585

# %%
log(exp(1))
# Out:
# [1] 1

# %%
log(c(10, 100, 1000))
# Out:
# [1] 2.302585 4.605170 6.907755

# %%
log10(10) #log(10) finds the log (with base 10) values
# Out:
# [1] 1

# %%
log10(100)
# Out:
# [1] 2

# %%
log10(1000)
# Out:
# [1] 3

# %%
log10(c(10, 100, 1000))
# Out:
# [1] 1 2 3

# %% [markdown]
# ***ASSIGMENT***

# %% [markdown]
# It can be use to save values in a variables

# %%
x1 = c(1,2,3,4)
x1
# Out:
# [1] 1 2 3 4

# %%
x2=x1^2
x2
# Out:
# [1]  1  4  9 16

# %% [markdown]
# Calculations with scalar, data vector and builnt in functions also work

# %%
c(1,2,3,4) + sum(c(1,2,3,4))
# Out:
# [1] 11 12 13 14

# %%
abs(c(1,2,3,4)) -sum(c(1,2,3,4))*prod(c(1,2,3,4))
# Out:
# [1] -239 -238 -237 -236

# %% [markdown]
# ***MATRICES***

# %% [markdown]
# In R, a 4 × 2‐matrix X can be created with a following command:

# %%
 X= matrix( nrow=4, ncol=2,
data=c(1,2,3,4,5,6,7,8) )

# %%
X
# Out:
#      [,1] [,2]
# [1,] 1    5
# [2,] 2    6
# [3,] 3    7
# [4,] 4    8

# %%
#nrow defines row number
#ncol defines column number
#data assignes specified value

#--of the matrix--

# %% [markdown]
# ***ACCESSING ANY ELEMENT OF A MATRIX***

# %%
x <- matrix(c(1,2,3,4,5,6,7,8), nrow = 4, ncol = 2)
x
# Out:
#      [,1] [,2]
# [1,] 1    5
# [2,] 2    6
# [3,] 3    7
# [4,] 4    8

# %% [markdown]
# ***ENTERING DATA COLUMN WISE IN A MATRIX***

# %%
x <- matrix(
  data = c(1,2,3,4,5,6,7,8),
  nrow = 4,
  ncol = 2
)

x
# Out:
#      [,1] [,2]
# [1,] 1    5
# [2,] 2    6
# [3,] 3    7
# [4,] 4    8

# %% [markdown]
# ***PROPETIES OF A MATRIX***

# %%
dim(x) #let us now the dimension of the matrix
# Out:
# [1] 4 2

# %%
nrow(x) #let us the no of rows
# Out:
# [1] 4

# %%
ncol(x) #let us know the no of columns
# Out:
# [1] 2

# %%
mode(x) # Informs the type or storage mode of an object, e.g., numerical, logical, etc
# Out:
# [1] "numeric"

# %%
attributes(x) #informs the dimension of the matrix
# Out:
# $dim
# [1] 4 2

# %% [markdown]
# ***HELP ON THE OBJECT "MATRIX"***

# %%
help("MATRIX")

# %% [markdown]
# ***--THANKYOU--***
