# %% [markdown]
# # R Programming NPTEL - Practical 2
#
# **Name:** Tamanna Shaikh
# **Roll No:** 24102A2006
# **Branch:** CMPN -A
# **Experiment Tittle:** Basics of Calculations, Basic Operations and R as a Calculator

# %% [markdown]
# ## Addition with data vectors
#
# Perform addition element-by-element on two data vectors.

# %%
c(2,3,5,7) + c(-2,-3,-5,8)
# Out:
# [1]  0  0  0 15

# %% [markdown]
# ## Addition with data vectors of different lengths
#
# Perform vector addition where the shorter vector is recycled.

# %%
c(2,3,5,7) + c(8,9)
# Out:
# [1] 10 12 13 16

# %% [markdown]
# ## Addition with non-multiple vector lengths
#
# Demonstrate vector recycling when the longer vector length is not a multiple of the shorter vector length.

# %%
c(2,3,5,7) + c(8,9,10)
# Out:
# Warning message in c(2, 3, 5, 7) + c(8, 9, 10):
# “longer object length is not a multiple of shorter object length”
# [1] 10 12 15 15

# %% [markdown]
# ## Subtraction with data vectors
#
# Perform subtraction element-by-element on two data vectors.

# %%
c(2,3,5,7) - c(-2,-3,-5,8)
# Out:
# [1]  4  6 10 -1

# %% [markdown]
# ## Subtraction with data vectors of different lengths
#
# Perform vector subtraction using recycling of the shorter vector.

# %%
c(12,13,15,17) - c(8,9)
# Out:
# [1] 4 4 7 8

# %% [markdown]
# ## Subtraction with non-multiple vector lengths
#
# Demonstrate recycling and the warning produced when vector lengths are not multiples.

# %%
c(12,13,15,17) - c(8,9,10)
# Out:
# Warning message in c(12, 13, 15, 17) - c(8, 9, 10):
# “longer object length is not a multiple of shorter object length”
# [1] 4 4 5 9

# %% [markdown]
# ## Multiplication with data vectors
#
# Perform element-by-element multiplication on two data vectors.

# %%
c(2,3,5,7) * c(-2,-3,-5,8)
# Out:
# [1]  -4  -9 -25  56

# %% [markdown]
# ## Multiplication with data vectors of different lengths
#
# Perform multiplication using vector recycling.

# %%
c(2,3,5,7) * c(8,9)
# Out:
# [1] 16 27 40 63

# %% [markdown]
# ## Multiplication with non-multiple vector lengths
#
# Demonstrate recycling and the warning for incompatible vector lengths.

# %%
c(2,3,5,7) * c(8,9,10)
# Out:
# Warning message in c(2, 3, 5, 7) * c(8, 9, 10):
# “longer object length is not a multiple of shorter object length”
# [1] 16 27 50 56

# %% [markdown]
# ## Division with data vectors
#
# Perform element-by-element division on two data vectors.

# %%
c(24,20,8,16) / c(3,4,2,8)
# Out:
# [1] 8 5 4 2

# %% [markdown]
# ## Division with data vectors of different lengths
#
# Perform division using recycling of the shorter vector.

# %%
c(24,20,8,16) / c(4,2)
# Out:
# [1]  6 10  2  8

# %% [markdown]
# ## Division with non-multiple vector lengths
#
# Demonstrate recycling and the warning for incompatible vector lengths.

# %%
c(24,20,8,16) / c(4,2,8)
# Out:
# Warning message in c(24, 20, 8, 16)/c(4, 2, 8):
# “longer object length is not a multiple of shorter object length”
# [1]  6 10  1  4

# %% [markdown]
# ## Assignment using the left-arrow operator
#
# Assign values to variables using the R assignment operator <-.

# %%
x <- 20
x
# Out:
# [1] 20

# %% [markdown]
# ## Assignment using the equal sign
#
# Assign values using the = assignment operator and use assigned variables in calculations.

# %%
x = 20
x
y = x * 2
y
z = x + y
z
# Out:
# [1] 20
# [1] 40
# [1] 60

# %% [markdown]
# ## Assignment of numbers and characters
#
# Assign numeric and character values using both assignment operators and quotes.

# %%
x = 20
x
x <- 20
x
x = "apple"
x
x <- "apple1"
x
x = 'apple'
x
x <- 'apple'
x
# Out:
# [1] 20
# [1] 20
# [1] "apple"
# [1] "apple1"
# [1] "apple"
# [1] "apple"

# %% [markdown]
# ## Checking whether a value is numeric or character
#
# Use is.numeric() and is.character() to identify the type of stored value.

# %%
x = 20
is.numeric(x)
is.character(x)

y = "apple"
is.character(y)
is.numeric(y)
# Out:
# [1] TRUE
# [1] FALSE
# [1] TRUE
# [1] FALSE

# %% [markdown]
# ## Converting a number into a character
#
# Convert a numeric value to character using as.character() and verify the result.

# %%
x = 20
is.numeric(x)

y = as.character(x)
is.numeric(y)
is.character(y)
y
# Out:
# [1] TRUE
# [1] FALSE
# [1] TRUE
# [1] "20"

# %% [markdown]
# ## Converting a character into a number
#
# Attempt to convert a non-numeric character to numeric using as.numeric() and observe the resulting NA and warning.

# %%
y = "apple"
is.numeric(y)
is.character(y)

z = as.numeric(y)
is.numeric(z)
is.character(z)
z
# Out:
# [1] FALSE
# [1] TRUE
# Warning message:
# “NAs introduced by coercion”
# [1] TRUE
# [1] FALSE
# [1] NA

# %% [markdown]
# ## Using the comment operator
#
# Use # to write comments that R ignores during execution.

# %%
# mu is the mean
# x <- 20 is treated as comment only

# %% [markdown]
# ## Case sensitivity in R
#
# Demonstrate that uppercase and lowercase variable names are different in R.

# %%
X <- 20
x <- 20
X
x
# Out:
# [1] 20
# [1] 20

# %% [markdown]
# ## Combining values in a data vector
#
# Use c() to combine individual values into a vector.

# %%
y = c(1,2,3,4,5)
y
# Out:
# [1] 1 2 3 4 5

# %% [markdown]
# ## Using mode() to identify object type
#
# Use mode() to identify the storage/type mode of numeric and character objects.

# %%
x = 6
x
mode(x)

y = "apple"
y
mode(y)
# Out:
# [1] 6
# [1] "numeric"
# [1] "apple"
# [1] "character"

# %% [markdown]
# ## Available modes in R
#
# Display the modes listed in the NPTEL material.

# %%
modes <- c("logical", "integer", "double", "complex", "raw",
           "character", "list", "expression", "name", "symbol", "function")
modes
# Out:
#  [1] "logical"    "integer"    "double"     "complex"    "raw"
#  [6] "character"  "list"       "expression" "name"       "symbol"
# [11] "function"

# %% [markdown]
# ## Using storage.mode()
#
# Use storage.mode() to inspect the storage mode of an R object.

# %%
x = 6
storage.mode(x)

x = TRUE
storage.mode(x)

x = "apple"
storage.mode(x)
# Out:
# [1] "double"
# [1] "logical"
# [1] "character"

# %% [markdown]
# ## Checking infinity in R
#
# Perform calculations that produce Inf and use is.finite() and is.infinite() to test the result.

# %%
3/0
5+Inf
x = 5+Inf
is.finite(x)
is.infinite(x)
# Out:
# [1] Inf
# [1] Inf
# [1] FALSE
# [1] TRUE

# %% [markdown]
# ## R as a calculator: scalar calculations
#
# Perform basic arithmetic calculations using scalars.

# %%
2+3
2*3
2-3
3/2
2*3-4+5/6
# Out:
# [1] 5
# [1] 6
# [1] -1
# [1] 1.5
# [1] 2.833333

# %% [markdown]
# ## Applying BODMAS rule
#
# Use brackets, powers, division, multiplication, addition and subtraction according to R's calculation order. The NPTEL material notes that only round brackets are used for BODMAS.

# %%
(2+3)*5 + 5 - 10
(((2+3)*5 + 5) - 10)/2
# Out:
# [1] 20
# [1] 10

# %% [markdown]
# ## Effect of blank spaces in calculations
#
# Demonstrate that blank spaces do not change the result of an arithmetic expression.

# %%
2+5
2 + 5
2    +    5
2 +5
# Out:
# [1] 7
# [1] 7
# [1] 7
# [1] 7

# %% [markdown]
# ## Addition with a scalar
#
# Add the scalar 10 to every element of a data vector.

# %%
c(2,3,5,7) + 10
# Out:
# [1] 12 13 15 17

# %% [markdown]
# ## Subtraction with a scalar
#
# Subtract the scalar 10 from every element of a data vector.

# %%
c(12,13,15,17) - 10
# Out:
# [1] 2 3 5 7

# %% [markdown]
# ## Multiplication with a scalar
#
# Multiply every element of a data vector by the scalar 10.

# %%
c(2,3,5,7) * 10
# Out:
# [1] 20 30 50 70

# %% [markdown]
# ## Division with a scalar
#
# Divide every element of a data vector by the scalar 10.

# %%
c(12,13,15,17) / 10
# Out:
# [1] 1.2 1.3 1.5 1.7
