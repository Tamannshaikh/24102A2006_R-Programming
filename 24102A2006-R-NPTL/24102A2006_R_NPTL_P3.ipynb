# %% [markdown]
# # R Programming NPTEL - Practical 3
#
# **Name:** Tamanna Shaikh
# **Roll No:** 24102A2006
# **Branch:** CMPN -A
# **Experiment Tittle:** Basics of Calculations, Built-in Functions and Matrices

# %% [markdown]
# ## Power operation using ^
#
# Perform a power calculation using the ^ operator.

# %%
2^3
# Out:
# [1] 8

# %% [markdown]
# ## Power operation using **
#
# Perform a power calculation using the ** operator.

# %%
2**3
# Out:
# [1] 8

# %% [markdown]
# ## Fractional power
#
# Calculate a square root using the power operator.

# %%
2^0.5
# Out:
# [1] 1.414214

# %% [markdown]
# ## Negative fractional power
#
# Calculate a negative fractional power.

# %%
2^-0.5
# Out:
# [1] 0.7071068

# %% [markdown]
# ## Power of a data vector
#
# Apply the power operation element-wise to a vector.

# %%
c(2,3,5,7)^2
# Out:
# [1]  4  9 25 49

# %% [markdown]
# ## Power operation with a vector
#
# Apply different exponents element-wise; the shorter vector is recycled.

# %%
c(2,3,5,7)^c(2,3)
# Out:
# [1]   4  27  25 343

# %% [markdown]
# ## Power operation with vectors of different lengths
#
# Apply vectorized powers and observe R's warning when lengths are not multiples.

# %%
c(1,2,3,4,5,6)^c(2,3,4)
# Out:
# [1]    1    8   81   16  125 1296

# %% [markdown]
# ## Power operation with non-multiple lengths
#
# Demonstrate vector recycling and its warning.

# %%
c(2,3,5,7)^c(2,3,4)
# Out:
# Warning message in c(2, 3, 5, 7)^c(2, 3, 4):
# “longer object length is not a multiple of shorter object length”
# [1]   4  27 625  49

# %% [markdown]
# ## Integer division with scalars
#
# Use %/% to perform integer division.

# %%
2 %/% 2
5 %/% 2
7 %/% 3
# Out:
# [1] 1
# [1] 2
# [1] 2

# %% [markdown]
# ## Integer division with a scalar
#
# Apply integer division to each vector element.

# %%
c(2,3,5,7) %/% 2
# Out:
# [1] 1 1 2 3

# %% [markdown]
# ## Integer division with a data vector
#
# Apply integer division using two vectors and recycling.

# %%
c(2,3,5,7) %/% c(2,3)
# Out:
# [1] 1 1 2 2

# %% [markdown]
# ## Integer division with non-multiple lengths
#
# Demonstrate integer division and the recycling warning.

# %%
c(2,3,5) %/% c(2,3)
# Out:
# Warning message in c(2, 3, 5)%/%c(2, 3):
# “longer object length is not a multiple of shorter object length”
# [1] 1 1 2

# %% [markdown]
# ## Modulo division with scalars
#
# Use %% to find remainders after division.

# %%
2 %% 2
3 %% 2
7 %% 3
7 %% 4
# Out:
# [1] 0
# [1] 1
# [1] 1
# [1] 3

# %% [markdown]
# ## Modulo division with a scalar
#
# Find the remainder for each element of a vector.

# %%
c(2,3,5,7) %% 2
# Out:
# [1] 0 1 1 1

# %% [markdown]
# ## Modulo division with data vectors
#
# Find remainders using two vectors with recycling.

# %%
c(2,3,5,7) %% c(2,3)
# Out:
# [1] 0 0 1 1

# %% [markdown]
# ## Modulo division with non-multiple lengths
#
# Demonstrate modulo operation and the recycling warning.

# %%
c(2,3,5) %% c(2,3)
# Out:
# Warning message in c(2, 3, 5)%%c(2, 3):
# “longer object length is not a multiple of shorter object length”
# [1] 0 0 1

# %% [markdown]
# ## Maximum of values
#
# Use max() to find the maximum value.

# %%
max(1.2, 3.4, -7.8)
max(c(1.2, 3.4, -7.8))
# Out:
# [1] 3.4
# [1] 3.4

# %% [markdown]
# ## Minimum of values
#
# Use min() to find the minimum value.

# %%
min(1.2, 3.4, -7.8)
min(c(1.2, 3.4, -7.8))
# Out:
# [1] -7.8
# [1] -7.8

# %% [markdown]
# ## Arithmetic mean
#
# Use mean() with separate arguments and with c().

# %%
mean(2, 3, 4)
mean(c(2, 3, 4))
# Out:
# [1] 2
# [1] 3

# %% [markdown]
# ## Absolute value
#
# Use abs() for scalar and vector values.

# %%
abs(-4)
abs(c(-1,-2,-3,4,5))
# Out:
# [1] 4
# [1] 1 2 3 4 5

# %% [markdown]
# ## Square root
#
# Use sqrt() for scalar and vector values.

# %%
sqrt(4)
sqrt(c(4,9,16,25))
# Out:
# [1] 2
# [1] 2 3 4 5

# %% [markdown]
# ## Sum of values
#
# Use sum() to calculate the total of vector values.

# %%
sum(c(2,3,5,7))
# Out:
# [1] 17

# %% [markdown]
# ## Product of values
#
# Use prod() to calculate the product of vector values.

# %%
prod(c(2,3,5,7))
# Out:
# [1] 210

# %% [markdown]
# ## Round values
#
# Use round() to round values.

# %%
round(1.23)
round(1.83)
# Out:
# [1] 1
# [1] 2

# %% [markdown]
# ## Natural logarithm
#
# Use log() to calculate natural logarithms.

# %%
log(10)
log(exp(1))
log(c(10,100,1000))
# Out:
# [1] 2.302585
# [1] 1
# [1] 2.302585 4.605170 6.907755

# %% [markdown]
# ## Base-10 logarithm
#
# Use log10() to calculate base-10 logarithms.

# %%
log10(10)
log10(100)
log10(c(10,100,1000))
# Out:
# [1] 1
# [1] 2
# [1] 1 2 3

# %% [markdown]
# ## Assignment with variables
#
# Save values in variables and perform a calculation.

# %%
x1 = c(1,2,3,4)
x1
x2 = x1^2
x2
# Out:
# [1] 1 2 3 4
# [1]  1  4  9 16

# %% [markdown]
# ## Calculation with scalar, vector and functions
#
# Combine a vector with sum() and prod() in a calculation.

# %%
c(1,2,3,4) + sum(c(1,2,3,4)) * prod(c(1,2))
abs(c(1,2,3,4) - sum(c(1,2,3,4))*prod(c(1,2)))
# Out:
# [1] 21 22 23 24
# [1] 19 18 17 16

# %% [markdown]
# ## Creating a 4 x 2 matrix
#
# Create a 4 x 2 matrix using matrix(); values are entered column-wise by default.

# %%
x = matrix(nrow=4, ncol=2, data=c(1,2,3,4,5,6,7,8))
x
# Out:
#      [,1] [,2]
# [1,] 1    5
# [2,] 2    6
# [3,] 3    7
# [4,] 4    8

# %% [markdown]
# ## Accessing a matrix element
#
# Access the element in row 3 and column 2.

# %%
x[3,2]
# Out:
# [1] 7

# %% [markdown]
# ## Entering matrix data column-wise
#
# Create a matrix explicitly using byrow = FALSE.

# %%
x = matrix(nrow=4, ncol=2, data=c(1,2,3,4,5,6,7,8), byrow=FALSE)
x
# Out:
#      [,1] [,2]
# [1,] 1    5
# [2,] 2    6
# [3,] 3    7
# [4,] 4    8

# %% [markdown]
# ## Entering matrix data row-wise
#
# Create a matrix using byrow = TRUE.

# %%
y = matrix(nrow=4, ncol=2, data=c(1,2,3,4,5,6,7,8), byrow=TRUE)
y
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
# [4,] 7    8

# %% [markdown]
# ## Matrix dimensions
#
# Use dim() to find matrix dimensions.

# %%
dim(x)
# Out:
# [1] 4 2

# %% [markdown]
# ## Number of rows
#
# Use nrow() to find the number of rows.

# %%
nrow(x)
# Out:
# [1] 4

# %% [markdown]
# ## Number of columns
#
# Use ncol() to find the number of columns.

# %%
ncol(x)
# Out:
# [1] 2

# %% [markdown]
# ## Matrix mode
#
# Use mode() to identify the matrix storage mode.

# %%
mode(x)
# Out:
# [1] "numeric"

# %% [markdown]
# ## Matrix attributes
#
# Use attributes() to display matrix attributes.

# %%
attributes(x)
# Out:
# $dim
# [1] 4 2

# %% [markdown]
# ## R help for matrix
#
# Open the built-in help for matrix().

# %%
help("matrix")

# %% [markdown]
# ## Testing a matrix
#
# Use is.matrix() to test whether an object is a matrix.

# %%
is.matrix(x)
# Out:
# [1] TRUE

# %% [markdown]
# ## Converting to a matrix
#
# Use as.matrix() and test the converted object.

# %%
is.matrix(as.matrix(1:10))
# Out:
# [1] TRUE

# %% [markdown]
# ## Data-frame and matrix example
#
# Use the warpbreaks example from the PDF to demonstrate data-frame versus matrix conversion.

# %%
data(warpbreaks)
!is.matrix(warpbreaks)
warpbreaks[1:10,]
as.matrix(warpbreaks[1:10,])
# Out:
# [1] TRUE
#    breaks wool tension
# 1  26     A    L
# 2  30     A    L
# 3  54     A    L
# 4  25     A    L
# 5  70     A    L
# 6  52     A    L
# 7  51     A    L
# 8  26     A    L
# 9  67     A    L
# 10 18     A    M
#    breaks wool tension
# 1  26     A    L
# 2  30     A    L
# 3  54     A    L
# 4  25     A    L
# 5  70     A    L
# 6  52     A    L
# 7  51     A    L
# 8  26     A    L
# 9  67     A    L
# 10 18     A    M
