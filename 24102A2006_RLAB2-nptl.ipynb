# %% [markdown]
# Name: Tamanna Shaikh
#
# Roll No: 24102A2006
#
# *R-Programming*
#
# **Lab 2**

# %% [markdown]
# ***BASICS OF CALCULATIONS***
#
# **CALCULATIONS WITH DATA VECTORS:**
#
# ADDITION, SUBTRACTION, MULTIPLICATION & DIVISION

# %% [markdown]
# ***ADDITION WITH DATA VECTORS***

# %%
c(2,3,5,7) + c(-2,-3,-5,8)
# Out:
# [1]  0  0  0 15

# %%
c(2,3,5,7) +c(8,9)
# Out:
# [1] 10 12 13 16

# %%
c(2,3,5,7) + c(8,9,10)
# Out:
# Warning message in c(2, 3, 5, 7) + c(8, 9, 10):
# “longer object length is not a multiple of shorter object length”
# [1] 10 12 15 15

# %% [markdown]
# ***SUBTRACTION WITH DATA VECTORS***

# %%
c(2,3,5,7) - c(-2,-3,-5,8)
# Out:
# [1]  4  6 10 -1

# %%
c(12,13,15,17) - c(9,0)
# Out:
# [1]  3 13  6 17

# %%
c(12,13,15,17) - c(8,9,10)
# Out:
# Warning message in c(12, 13, 15, 17) - c(8, 9, 10):
# “longer object length is not a multiple of shorter object length”
# [1] 4 4 5 9

# %% [markdown]
# ***MULTIPLICATION WITH DATA VECTORS***

# %%
c(2,3,5,7) * c(-2,-3,-5,8)
# Out:
# [1]  -4  -9 -25  56

# %%
c(2,3,5,7) * c(8,9
)
# Out:
# [1] 16 27 40 63

# %%
c(2,3,5,7) * c(8,9,10)
# Out:
# Warning message in c(2, 3, 5, 7) * c(8, 9, 10):
# “longer object length is not a multiple of shorter object length”
# [1] 16 27 50 56

# %% [markdown]
# **DIVISION WITH DATA VECTORS**

# %%
c(24,20,8,16) / c(3,4,2,8)
# Out:
# [1] 8 5 4 2

# %%
c(2,3,5,7) * c(4,2)
# Out:
# [1]  8  6 20 14

# %%
c(2,3,5,7) * c(4,2,8)
# Out:
# Warning message in c(2, 3, 5, 7) * c(4, 2, 8):
# “longer object length is not a multiple of shorter object length”
# [1]  8  6 40 28

# %% [markdown]
# ***ASSIGNMENT OF NUMBERS AND CHARACTERS***

# %% [markdown]
# Assignment of numbers and characters.
#
# About numbers:
#
# x <- 20 assigns value 20 to x
#
# x = 20 assigns the value 20 to x

# %% [markdown]
# About characters, they are assigned within double or single quotes.
#
# x = "apple" **OR** x <- "apple" **OR** x= 'apple' **OR** x <- 'apple'
#
# all these above are the ways where the word - apple - assigns to x

# %%
x = 20
x

x = "apple"
x


x = "apple"
# Out:
# [1] 20
# [1] "apple"

# %% [markdown]
# ***KNOWING NUMBERS AND CHARACTERS***

# %%
x = 20
is.numeric(x) #To know if a value is a number, use is.numeric()

is.character(x) #To know if a value is a character, use is.character()

y="apple"
is.character(y)

is.numeric(y)
# Out:
# [1] TRUE
# [1] FALSE
# [1] TRUE
# [1] FALSE

# %% [markdown]
# ***CONVERTING NUMBERS AND CHARACTERS***

# %%
X=20
is.numeric(x) #To convert a value as a number, use as.numeric()

y=as.character(x) #To convert a value as a character, use as.character()

is.numeric(y)

is.character(y)

y
# Out:
# [1] TRUE
# [1] FALSE
# [1] TRUE
# [1] "20"

# %% [markdown]
# ***CONVERTING NUMBERS AND CHARACTERS***
#
# **Converting a character into a number**

# %%
y = "apple"
is.numeric(y)
is.character(y)
z = as.numeric(y)
is.numeric(z)
 is.character(z)
 z
# Out:
# [1] FALSE
# [1] TRUE
# Warning message:
# “NAs introduced by coercion”
# [1] TRUE
# [1] FALSE
# [1] NA

# %% [markdown]
# ***COMMENT OPERATOR***

# %%
# : The character # marks the beginning of a comment.

# %%
 # x <- 20 is treated as comment

# %%
x<- 20
x
# Out:
# [1] 20

# %% [markdown]
# ***CASE SENSITIVITY IN R***

# %%
#X <- 20 and x <- 20 are different

# %%
x<-20
x

X

X<- 30
X
x
# Out:
# [1] 20
# [1] 30
# [1] 30
# [1] 20

# %%
y=1,2,3,4,5
# Out:
# Error in parse(text = input): <text>:1:4: unexpected ','
# 1: y=1,
#        ^
# Traceback:

# %%
y=(1,2,3,4,5)
# Out:
# Error in parse(text = input): <text>:1:5: unexpected ','
# 1: y=(1,
#         ^
# Traceback:

# %% [markdown]
# ***COMBINING VALUES IN A DATA VECTOR***

# %%
y=c(1,2,3,4,5)
y
# Out:
# [1] 1 2 3 4 5

# %%
x=6
x
mode(x)

y="apple"
y
mode(y)
# Out:
# [1] 6
# [1] "numeric"
# [1] "apple"
# [1] "character"

# %% [markdown]
# ***MODE EXAMPLES***

# %%
x=6 #numeric
storage.mode(x) #Command storage.mode() returns the storage mode of its argument.
# Out:
# [1] "double"

# %%
x=TRUE #LOGICAL
storage.mode(x)
# Out:
# [1] "logical"

# %%
x="apple" #character
storage.mode(x)
# Out:
# [1] "character"

# %% [markdown]
# ***INFINITY***

# %%
3/0

#ome calculations yield result as infinity (∞).
#For example, 3/0. In R  is.finite() and  is.infinite() are used to know if an outcome is finite or infinite, respectively

5+Inf

x=5+Inf
is.finite(x)
is.infinite(x)
# Out:
# [1] Inf
# [1] Inf
# [1] FALSE
# [1] TRUE

# %% [markdown]
# *R AS CALCULATOR*

# %%
2+3 #addition command

2*3 #multiplication commmand
# Out:
# [1] 5
# [1] 6

# %%
2-3 #subtraction command

3/2 #division command

2*3-4+5/6
# Out:
# [1] -1
# [1] 1.5
# [1] 2.833333

# %% [markdown]
# *R AS A CALCULATOR BODMAS*

# %%
(2+3)*5+5-10 #COMMAND FOR BODMAS
# Out:
# [1] 20

# %%
(((2+3)*5+5) -10)/2 #COMMAND FOR BODMAS
# Out:
# [1] 10

# %% [markdown]
# ***BLANK SPACE HAS NO ROLE IN CALCULATIONS***

# %%
#Blank space has no role in calculation

# %%
2+5
# Out:
# [1] 7

# %%
2 + 5
# Out:
# [1] 7

# %%
2  +  5
# Out:
# [1] 7

# %%
2  +5
# Out:
# [1] 7

# %% [markdown]
# ***ADDITION WITH SCALAR***

# %%
c(2,3,5,7) + 10
# Out:
# [1] 12 13 15 17

# %% [markdown]
# ***SUBTRACTION WITH SCALAR***

# %%
c(12,13,15,17) - 10
# Out:
# [1] 2 3 5 7

# %% [markdown]
# ***MULTIPLICATION WITH SCALAR***

# %%
c(2,3,5,7) * 10
# Out:
# [1] 20 30 50 70

# %% [markdown]
# ***DIVISION WITH SCALAR***

# %%
c(12,13,15,17) / 10
# Out:
# [1] 1.2 1.3 1.5 1.7

# %% [markdown]
# ***--THANKYOU--***
